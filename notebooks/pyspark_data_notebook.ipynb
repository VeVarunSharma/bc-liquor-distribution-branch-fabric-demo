# %% [markdown]
# # BC Liquor Distribution PySpark notebook
#
# This notebook normalizes branch names, handles missing values, and summarizes revenue by branch.

# %%
from notebook import fix_pyspark_data_notebook_bug

result = fix_pyspark_data_notebook_bug(data_path='data/liquor_distribution_sample.csv')
result.show()
